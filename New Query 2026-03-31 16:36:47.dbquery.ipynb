-- %%
select * from `workspace`.`brighttv`.`bright_tv_dataset` limit 100;

--1. Counting the number of users in each province
SELECT count(UserID), Province
FROM `workspace`.`brighttv`.`bright_tv_dataset`
GROUP BY Province;
